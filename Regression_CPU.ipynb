# %%
#1.
import numpy as np
import pandas as pd
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt

from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split, KFold, GridSearchCV, RandomizedSearchCV, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, explained_variance_score

#Regression algorythms
from sklearn.linear_model import Ridge, Lasso
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor

from xgboost import XGBRegressor
from catboost import CatBoostRegressor

# %%
#2. Data split
diabetes = load_diabetes()
X = diabetes.data
y = diabetes.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=345)

# %%
#3. Data standardization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
#4.
models = [
    ('Ridge Regression', Ridge()),
    ('Lasso Regression', Lasso()),
    ('SVR', SVR()),
    ('Decision Tree', DecisionTreeRegressor()),
    ('Random Forest', RandomForestRegressor()),
    ('k-NN', KNeighborsRegressor()),
    ('Gradient Boosting', GradientBoostingRegressor()),
    ('Neural Network', MLPRegressor(max_iter=10000)),
    ('XGBoost', XGBRegressor(objective='reg:squarederror')),
    ('CatBoost', CatBoostRegressor(verbose=0))
]

# %%
#5. Cross-validation parameters
cv = KFold(n_splits=5, shuffle=True, random_state=345)

# %%
#6.
def evaluate_model(name, model, X_train, y_train, cv):
    nmse_scores = cross_val_score(model, X_train, y_train, cv=cv, scoring='neg_mean_squared_error')
    nmae_scores = cross_val_score(model, X_train, y_train, cv=cv, scoring='neg_mean_absolute_error')
    r2_scores = cross_val_score(model, X_train, y_train, cv=cv, scoring='r2')
    ev_scores = cross_val_score(model, X_train, y_train, cv=cv, scoring='explained_variance')

    return {
        'Model': name,
        'MSE': -nmse_scores.mean(),  # Convert NMSE to MSE
        'MAE': -nmae_scores.mean(),  # Convert NMAE to MAE
        'R2': r2_scores.mean(),
        'Explained Variance': ev_scores.mean()
    }

def evaluate_models(models, X_train, y_train, cv):
    return [evaluate_model(name, model, X_train, y_train, cv) for name, model in models]

# %%
#7. Default hyperparameters
default_results = evaluate_models(models, X_train, y_train, cv)
df_default = pd.DataFrame(default_results)

# %%
#8. Defining hyperparameter grids for individual models

param_grids = {
    'Ridge Regression': {
        'alpha': [0.01, 0.1, 1.0, 2.0, 5.0, 10.0, 20.0, 50.0, 100.0]
    },
    'Lasso Regression': {
        'alpha': [0.01, 0.1, 1.0, 2.0, 5.0, 10.0, 20.0, 50.0, 100.0]
    },
    'SVR': {
        'C': [0.01, 0.1, 1.0, 2.0, 5.0, 10.0, 20.0, 50.0, 100.0],
        'gamma': [0.001, 0.01, 0.1, 0.2, 0.5, 1],
        'kernel': ['rbf', 'linear']
    },
    'Decision Tree': {
        'max_depth': [None, 2, 5, 10, 20, 30, 40, 50, 100],
        'min_samples_split': [2, 4, 5, 6, 8, 10, 12, 15],
        'min_samples_leaf': [1, 2, 4, 5, 8, 10]
    },
    'Random Forest': {
        'n_estimators': [10, 25, 40, 50, 80, 100],
        'max_depth': [None, 5, 10, 20, 25, 30, 40],
        'min_samples_split': [2, 5, 8, 10],
        'min_samples_leaf': [1, 2, 4, 5, 8, 10, 15]
    },
    'k-NN': {
        'n_neighbors': [3, 5, 7, 9, 11],
        'weights': ['uniform', 'distance'],
        'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']
    },
    'Gradient Boosting': {
        'n_estimators': [10, 20, 25, 30, 40, 50, 80, 100, 150, 200],
        'learning_rate': [0.001, 0.01, 0.1, 0.2, 0.5, 1],
        'max_depth': [3, 5, 7, 9, 11]
    },
    'Neural Network': {
        'hidden_layer_sizes': [(50,), (100,)],
        'activation': ['relu', 'tanh'],
        'solver': ['adam', 'lbfgs'],
        'alpha': [0.0001, 0.01],
        'learning_rate': ['constant', 'adaptive']
    },
    'XGBoost': {
        'n_estimators': [50, 75, 100, 200],
        'learning_rate': [0.01, 0.1, 0.2, 0.3],
        'max_depth': [3, 5, 7, 9]
    },
    'CatBoost': {
        'iterations': [100, 200, 500],
        'learning_rate': [0.01, 0.1, 0.2, 0.3],
        'depth': [3, 5, 7, 9]
    }

}

# %%
#9. 
best_models = []
for name, model in models:
    print(f"Tuning {name}...")
    grid_search = GridSearchCV(estimator=model, param_grid=param_grids[name], cv=cv, scoring='neg_mean_squared_error', n_jobs=-1)
    grid_search.fit(X_train, y_train)
    best_models.append((name, grid_search.best_estimator_, grid_search.best_params_))
    print(f"Best parameters for {name}: {grid_search.best_params_}")
# Out:
# Tuning Ridge Regression...
# Best parameters for Ridge Regression: {'alpha': 5.0}
# Tuning Lasso Regression...
# Best parameters for Lasso Regression: {'alpha': 1.0}
# Tuning SVR...
# Best parameters for SVR: {'C': 50.0, 'gamma': 0.01, 'kernel': 'rbf'}
# Tuning Decision Tree...
# Best parameters for Decision Tree: {'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Tuning Random Forest...
# Best parameters for Random Forest: {'max_depth': 20, 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 50}
# Tuning k-NN...
# Best parameters for k-NN: {'algorithm': 'auto', 'n_neighbors': 7, 'weights': 'distance'}
# Tuning Gradient Boosting...
# Best parameters for Gradient Boosting: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}
# Tuning Neural Network...
# c:\Users\cezar\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Best parameters for Neural Network: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50,), 'learning_rate': 'constant', 'solver': 'adam'}
# Tuning XGBoost...
# Best parameters for XGBoost: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}
# Tuning CatBoost...
# Best parameters for CatBoost: {'depth': 3, 'iterations': 100, 'learning_rate': 0.1}

# %%
#10. 
tuned_results = evaluate_models([(name, model) for name, model, params in best_models], X_train, y_train, cv)
df_tuned = pd.DataFrame(tuned_results)

# %%
#13.
def styled_df(df):
    styled_df = df.style.background_gradient(subset=['R2', 'Explained Variance'], cmap='RdYlGn')
    styled_df = styled_df.background_gradient(subset=['MSE', 'MAE'], cmap='RdYlGn_r') #reverse color map for minimized metrics
    return styled_df

# %%
#14.1.
styled_df(df_default)
# Out:
# <style type="text/css">
# #T_1b665_row0_col1, #T_1b665_row0_col4 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_1b665_row0_col2, #T_1b665_row0_col3 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_1b665_row1_col1, #T_1b665_row1_col2, #T_1b665_row1_col3, #T_1b665_row1_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_1b665_row2_col1 {
#   background-color: #fece7c;
#   color: #000000;
# }
# #T_1b665_row2_col2 {
#   background-color: #e44c34;
#   color: #f1f1f1;
# }
# #T_1b665_row2_col3 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_1b665_row2_col4 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_1b665_row3_col1, #T_1b665_row3_col2, #T_1b665_row3_col3, #T_1b665_row3_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_1b665_row4_col1 {
#   background-color: #39a758;
#   color: #f1f1f1;
# }
# #T_1b665_row4_col2 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_1b665_row4_col3, #T_1b665_row6_col2, #T_1b665_row6_col3 {
#   background-color: #48ae5c;
#   color: #f1f1f1;
# }
# #T_1b665_row4_col4, #T_1b665_row6_col1, #T_1b665_row7_col2 {
#   background-color: #3faa59;
#   color: #f1f1f1;
# }
# #T_1b665_row5_col1 {
#   background-color: #6ec064;
#   color: #000000;
# }
# #T_1b665_row5_col2 {
#   background-color: #6bbf64;
#   color: #000000;
# }
# #T_1b665_row5_col3, #T_1b665_row5_col4 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_1b665_row6_col4, #T_1b665_row7_col1 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_1b665_row7_col3 {
#   background-color: #54b45f;
#   color: #f1f1f1;
# }
# #T_1b665_row7_col4 {
#   background-color: #7ac665;
#   color: #000000;
# }
# #T_1b665_row8_col1 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_1b665_row8_col2 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_1b665_row8_col3 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_1b665_row8_col4 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_1b665_row9_col1 {
#   background-color: #36a657;
#   color: #f1f1f1;
# }
# #T_1b665_row9_col2 {
#   background-color: #69be63;
#   color: #f1f1f1;
# }
# #T_1b665_row9_col3 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_1b665_row9_col4 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1b665">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b665_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1b665_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_1b665_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_1b665_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_1b665_level0_col4" class="col_heading level0 col4" >Explained Variance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b665_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1b665_row0_col0" class="data row0 col0" >Ridge Regression</td>
#       <td id="T_1b665_row0_col1" class="data row0 col1" >3017.384479</td>
#       <td id="T_1b665_row0_col2" class="data row0 col2" >44.988392</td>
#       <td id="T_1b665_row0_col3" class="data row0 col3" >0.455947</td>
#       <td id="T_1b665_row0_col4" class="data row0 col4" >0.470067</td>
#     </tr>
#     <tr>
#       <th id="T_1b665_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1b665_row1_col0" class="data row1 col0" >Lasso Regression</td>
#       <td id="T_1b665_row1_col1" class="data row1 col1" >3002.962386</td>
#       <td id="T_1b665_row1_col2" class="data row1 col2" >44.841481</td>
#       <td id="T_1b665_row1_col3" class="data row1 col3" >0.460822</td>
#       <td id="T_1b665_row1_col4" class="data row1 col4" >0.473699</td>
#     </tr>
#     <tr>
#       <th id="T_1b665_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1b665_row2_col0" class="data row2 col0" >SVR</td>
#       <td id="T_1b665_row2_col1" class="data row2 col1" >5048.658620</td>
#       <td id="T_1b665_row2_col2" class="data row2 col2" >60.023966</td>
#       <td id="T_1b665_row2_col3" class="data row2 col3" >0.118126</td>
#       <td id="T_1b665_row2_col4" class="data row2 col4" >0.144811</td>
#     </tr>
#     <tr>
#       <th id="T_1b665_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1b665_row3_col0" class="data row3 col0" >Decision Tree</td>
#       <td id="T_1b665_row3_col1" class="data row3 col1" >6222.294889</td>
#       <td id="T_1b665_row3_col2" class="data row3 col2" >62.601932</td>
#       <td id="T_1b665_row3_col3" class="data row3 col3" >-0.088947</td>
#       <td id="T_1b665_row3_col4" class="data row3 col4" >-0.089226</td>
#     </tr>
#     <tr>
#       <th id="T_1b665_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1b665_row4_col0" class="data row4 col0" >Random Forest</td>
#       <td id="T_1b665_row4_col1" class="data row4 col1" >3456.303020</td>
#       <td id="T_1b665_row4_col2" class="data row4 col2" >48.399870</td>
#       <td id="T_1b665_row4_col3" class="data row4 col3" >0.372536</td>
#       <td id="T_1b665_row4_col4" class="data row4 col4" >0.389532</td>
#     </tr>
#     <tr>
#       <th id="T_1b665_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1b665_row5_col0" class="data row5 col0" >k-NN</td>
#       <td id="T_1b665_row5_col1" class="data row5 col1" >3685.557257</td>
#       <td id="T_1b665_row5_col2" class="data row5 col2" >48.579219</td>
#       <td id="T_1b665_row5_col3" class="data row5 col3" >0.340087</td>
#       <td id="T_1b665_row5_col4" class="data row5 col4" >0.349525</td>
#     </tr>
#     <tr>
#       <th id="T_1b665_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1b665_row6_col0" class="data row6 col0" >Gradient Boosting</td>
#       <td id="T_1b665_row6_col1" class="data row6 col1" >3484.199293</td>
#       <td id="T_1b665_row6_col2" class="data row6 col2" >47.711965</td>
#       <td id="T_1b665_row6_col3" class="data row6 col3" >0.371055</td>
#       <td id="T_1b665_row6_col4" class="data row6 col4" >0.377206</td>
#     </tr>
#     <tr>
#       <th id="T_1b665_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1b665_row7_col0" class="data row7 col0" >Neural Network</td>
#       <td id="T_1b665_row7_col1" class="data row7 col1" >3546.161147</td>
#       <td id="T_1b665_row7_col2" class="data row7 col2" >47.508688</td>
#       <td id="T_1b665_row7_col3" class="data row7 col3" >0.364137</td>
#       <td id="T_1b665_row7_col4" class="data row7 col4" >0.343338</td>
#     </tr>
#     <tr>
#       <th id="T_1b665_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1b665_row8_col0" class="data row8 col0" >XGBoost</td>
#       <td id="T_1b665_row8_col1" class="data row8 col1" >4167.346671</td>
#       <td id="T_1b665_row8_col2" class="data row8 col2" >52.814794</td>
#       <td id="T_1b665_row8_col3" class="data row8 col3" >0.244190</td>
#       <td id="T_1b665_row8_col4" class="data row8 col4" >0.263011</td>
#     </tr>
#     <tr>
#       <th id="T_1b665_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1b665_row9_col0" class="data row9 col0" >CatBoost</td>
#       <td id="T_1b665_row9_col1" class="data row9 col1" >3452.565694</td>
#       <td id="T_1b665_row9_col2" class="data row9 col2" >48.454933</td>
#       <td id="T_1b665_row9_col3" class="data row9 col3" >0.376479</td>
#       <td id="T_1b665_row9_col4" class="data row9 col4" >0.384748</td>
#     </tr>
#   </tbody>
# </table>

# %%
#14.2.
styled_df(df_tuned)
# Out:
# <style type="text/css">
# #T_a1dae_row0_col1, #T_a1dae_row0_col2 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_a1dae_row0_col3 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_a1dae_row0_col4 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
# }
# #T_a1dae_row1_col1, #T_a1dae_row1_col2 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_a1dae_row1_col3 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_a1dae_row1_col4 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_a1dae_row2_col1, #T_a1dae_row2_col2, #T_a1dae_row2_col3, #T_a1dae_row2_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_a1dae_row3_col1, #T_a1dae_row3_col2, #T_a1dae_row3_col3, #T_a1dae_row3_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_a1dae_row4_col1, #T_a1dae_row4_col3 {
#   background-color: #bfe47a;
#   color: #000000;
# }
# #T_a1dae_row4_col2 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_a1dae_row4_col4 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_a1dae_row5_col1 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_a1dae_row5_col2 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_a1dae_row5_col3 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_a1dae_row5_col4 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_a1dae_row6_col1 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_a1dae_row6_col2, #T_a1dae_row8_col1 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_a1dae_row6_col3 {
#   background-color: #dcf08f;
#   color: #000000;
# }
# #T_a1dae_row6_col4 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_a1dae_row7_col1 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_a1dae_row7_col2 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_a1dae_row7_col3 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_a1dae_row7_col4 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_a1dae_row8_col2 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_a1dae_row8_col3 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_a1dae_row8_col4 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_a1dae_row9_col1 {
#   background-color: #30a356;
#   color: #f1f1f1;
# }
# #T_a1dae_row9_col2 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_a1dae_row9_col3 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_a1dae_row9_col4 {
#   background-color: #57b65f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a1dae">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1dae_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a1dae_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_a1dae_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_a1dae_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_a1dae_level0_col4" class="col_heading level0 col4" >Explained Variance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1dae_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a1dae_row0_col0" class="data row0 col0" >Ridge Regression</td>
#       <td id="T_a1dae_row0_col1" class="data row0 col1" >3015.265061</td>
#       <td id="T_a1dae_row0_col2" class="data row0 col2" >44.888230</td>
#       <td id="T_a1dae_row0_col3" class="data row0 col3" >0.457149</td>
#       <td id="T_a1dae_row0_col4" class="data row0 col4" >0.470543</td>
#     </tr>
#     <tr>
#       <th id="T_a1dae_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a1dae_row1_col0" class="data row1 col0" >Lasso Regression</td>
#       <td id="T_a1dae_row1_col1" class="data row1 col1" >3002.962386</td>
#       <td id="T_a1dae_row1_col2" class="data row1 col2" >44.841481</td>
#       <td id="T_a1dae_row1_col3" class="data row1 col3" >0.460822</td>
#       <td id="T_a1dae_row1_col4" class="data row1 col4" >0.473699</td>
#     </tr>
#     <tr>
#       <th id="T_a1dae_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a1dae_row2_col0" class="data row2 col0" >SVR</td>
#       <td id="T_a1dae_row2_col1" class="data row2 col1" >2998.148894</td>
#       <td id="T_a1dae_row2_col2" class="data row2 col2" >44.802185</td>
#       <td id="T_a1dae_row2_col3" class="data row2 col3" >0.462328</td>
#       <td id="T_a1dae_row2_col4" class="data row2 col4" >0.477003</td>
#     </tr>
#     <tr>
#       <th id="T_a1dae_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a1dae_row3_col0" class="data row3 col0" >Decision Tree</td>
#       <td id="T_a1dae_row3_col1" class="data row3 col1" >3889.810261</td>
#       <td id="T_a1dae_row3_col2" class="data row3 col2" >49.963001</td>
#       <td id="T_a1dae_row3_col3" class="data row3 col3" >0.304464</td>
#       <td id="T_a1dae_row3_col4" class="data row3 col4" >0.323282</td>
#     </tr>
#     <tr>
#       <th id="T_a1dae_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a1dae_row4_col0" class="data row4 col0" >Random Forest</td>
#       <td id="T_a1dae_row4_col1" class="data row4 col1" >3311.338665</td>
#       <td id="T_a1dae_row4_col2" class="data row4 col2" >47.345828</td>
#       <td id="T_a1dae_row4_col3" class="data row4 col3" >0.407433</td>
#       <td id="T_a1dae_row4_col4" class="data row4 col4" >0.422197</td>
#     </tr>
#     <tr>
#       <th id="T_a1dae_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a1dae_row5_col0" class="data row5 col0" >k-NN</td>
#       <td id="T_a1dae_row5_col1" class="data row5 col1" >3445.401476</td>
#       <td id="T_a1dae_row5_col2" class="data row5 col2" >47.025107</td>
#       <td id="T_a1dae_row5_col3" class="data row5 col3" >0.385431</td>
#       <td id="T_a1dae_row5_col4" class="data row5 col4" >0.395019</td>
#     </tr>
#     <tr>
#       <th id="T_a1dae_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a1dae_row6_col0" class="data row6 col0" >Gradient Boosting</td>
#       <td id="T_a1dae_row6_col1" class="data row6 col1" >3357.308729</td>
#       <td id="T_a1dae_row6_col2" class="data row6 col2" >47.491035</td>
#       <td id="T_a1dae_row6_col3" class="data row6 col3" >0.397905</td>
#       <td id="T_a1dae_row6_col4" class="data row6 col4" >0.405472</td>
#     </tr>
#     <tr>
#       <th id="T_a1dae_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a1dae_row7_col0" class="data row7 col0" >Neural Network</td>
#       <td id="T_a1dae_row7_col1" class="data row7 col1" >3552.083075</td>
#       <td id="T_a1dae_row7_col2" class="data row7 col2" >46.158026</td>
#       <td id="T_a1dae_row7_col3" class="data row7 col3" >0.399357</td>
#       <td id="T_a1dae_row7_col4" class="data row7 col4" >0.400413</td>
#     </tr>
#     <tr>
#       <th id="T_a1dae_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a1dae_row8_col0" class="data row8 col0" >XGBoost</td>
#       <td id="T_a1dae_row8_col1" class="data row8 col1" >3461.701999</td>
#       <td id="T_a1dae_row8_col2" class="data row8 col2" >48.454532</td>
#       <td id="T_a1dae_row8_col3" class="data row8 col3" >0.376167</td>
#       <td id="T_a1dae_row8_col4" class="data row8 col4" >0.389286</td>
#     </tr>
#     <tr>
#       <th id="T_a1dae_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a1dae_row9_col0" class="data row9 col0" >CatBoost</td>
#       <td id="T_a1dae_row9_col1" class="data row9 col1" >3114.725718</td>
#       <td id="T_a1dae_row9_col2" class="data row9 col2" >45.809044</td>
#       <td id="T_a1dae_row9_col3" class="data row9 col3" >0.437775</td>
#       <td id="T_a1dae_row9_col4" class="data row9 col4" >0.448923</td>
#     </tr>
#   </tbody>
# </table>
