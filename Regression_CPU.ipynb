# %%
import numpy as np
import pandas as pd

from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split, cross_val_score, KFold, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import make_scorer, mean_squared_error, mean_absolute_error, r2_score, median_absolute_error, mean_squared_log_error, explained_variance_score

#Regression algorythms
from sklearn.linear_model import Ridge, Lasso
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor

# %%
#Data split
diabetes = load_diabetes()
X = diabetes.data
y = diabetes.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=345)

# %%
#Data standardization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
models = [
    ('Ridge Regression', Ridge()),
    ('Lasso Regression', Lasso()),
    ('SVR', SVR()),
    ('Decision Tree', DecisionTreeRegressor()),
    ('Random Forest', RandomForestRegressor()),
    ('k-NN', KNeighborsRegressor()),
    ('Gradient Boosting', GradientBoostingRegressor()),
    ('Neural Network', MLPRegressor(max_iter=10000))
]

# %%
#Cross-validation parameters
cv = KFold(n_splits=5, shuffle=True, random_state=345)

# %%
scoring = {
    'neg_mean_squared_error': make_scorer(mean_squared_error, greater_is_better=False),
    'neg_mean_absolute_error': make_scorer(mean_absolute_error, greater_is_better=False),
    'r2': make_scorer(r2_score),
    'neg_median_absolute_error': make_scorer(median_absolute_error, greater_is_better=False),
    'neg_mean_squared_log_error': make_scorer(mean_squared_log_error, greater_is_better=False),
    'explained_variance': make_scorer(explained_variance_score)
}

# %%
#Default hyperparameters
results = []
names = []

for name, model in models:
    scores = {metric: cross_val_score(model, X_train, y_train, cv=cv, scoring=scorer).mean() for metric, scorer in scoring.items()}
    results.append(scores)
    names.append(name)

results_df = pd.DataFrame(results, index=names)
# Out:
# c:\Users\cezar\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\cezar\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\cezar\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\cezar\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\cezar\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10000) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
results_df.style.background_gradient(cmap="RdYlGn")
# Out:
# <style type="text/css">
# #T_5d7b8_row0_col0, #T_5d7b8_row0_col2, #T_5d7b8_row0_col5 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_5d7b8_row0_col1, #T_5d7b8_row1_col3 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_5d7b8_row0_col3, #T_5d7b8_row1_col0, #T_5d7b8_row1_col1, #T_5d7b8_row1_col2, #T_5d7b8_row1_col4, #T_5d7b8_row1_col5, #T_5d7b8_row7_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_5d7b8_row0_col4 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_5d7b8_row2_col0 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_5d7b8_row2_col1 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_5d7b8_row2_col2 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_5d7b8_row2_col3, #T_5d7b8_row3_col0, #T_5d7b8_row3_col1, #T_5d7b8_row3_col2, #T_5d7b8_row3_col4, #T_5d7b8_row3_col5 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_5d7b8_row2_col4, #T_5d7b8_row2_col5 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_5d7b8_row3_col3 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_5d7b8_row4_col0 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_5d7b8_row4_col1 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_5d7b8_row4_col2, #T_5d7b8_row7_col0 {
#   background-color: #33a456;
#   color: #f1f1f1;
# }
# #T_5d7b8_row4_col3 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_5d7b8_row4_col4 {
#   background-color: #30a356;
#   color: #f1f1f1;
# }
# #T_5d7b8_row4_col5 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_5d7b8_row5_col0 {
#   background-color: #6ec064;
#   color: #000000;
# }
# #T_5d7b8_row5_col1, #T_5d7b8_row5_col5 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_5d7b8_row5_col2, #T_5d7b8_row6_col3 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_5d7b8_row5_col3 {
#   background-color: #199750;
#   color: #f1f1f1;
# }
# #T_5d7b8_row5_col4 {
#   background-color: #5db961;
#   color: #f1f1f1;
# }
# #T_5d7b8_row6_col0, #T_5d7b8_row6_col2 {
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# #T_5d7b8_row6_col1 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# #T_5d7b8_row6_col4 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_5d7b8_row6_col5 {
#   background-color: #48ae5c;
#   color: #f1f1f1;
# }
# #T_5d7b8_row7_col1 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_5d7b8_row7_col2 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_5d7b8_row7_col4 {
#   background-color: #3faa59;
#   color: #f1f1f1;
# }
# #T_5d7b8_row7_col5 {
#   background-color: #57b65f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5d7b8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d7b8_level0_col0" class="col_heading level0 col0" >neg_mean_squared_error</th>
#       <th id="T_5d7b8_level0_col1" class="col_heading level0 col1" >neg_mean_absolute_error</th>
#       <th id="T_5d7b8_level0_col2" class="col_heading level0 col2" >r2</th>
#       <th id="T_5d7b8_level0_col3" class="col_heading level0 col3" >neg_median_absolute_error</th>
#       <th id="T_5d7b8_level0_col4" class="col_heading level0 col4" >neg_mean_squared_log_error</th>
#       <th id="T_5d7b8_level0_col5" class="col_heading level0 col5" >explained_variance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d7b8_level0_row0" class="row_heading level0 row0" >Ridge Regression</th>
#       <td id="T_5d7b8_row0_col0" class="data row0 col0" >-3017.384479</td>
#       <td id="T_5d7b8_row0_col1" class="data row0 col1" >-44.988392</td>
#       <td id="T_5d7b8_row0_col2" class="data row0 col2" >0.455947</td>
#       <td id="T_5d7b8_row0_col3" class="data row0 col3" >-39.391947</td>
#       <td id="T_5d7b8_row0_col4" class="data row0 col4" >-0.171642</td>
#       <td id="T_5d7b8_row0_col5" class="data row0 col5" >0.470067</td>
#     </tr>
#     <tr>
#       <th id="T_5d7b8_level0_row1" class="row_heading level0 row1" >Lasso Regression</th>
#       <td id="T_5d7b8_row1_col0" class="data row1 col0" >-3002.962386</td>
#       <td id="T_5d7b8_row1_col1" class="data row1 col1" >-44.841481</td>
#       <td id="T_5d7b8_row1_col2" class="data row1 col2" >0.460822</td>
#       <td id="T_5d7b8_row1_col3" class="data row1 col3" >-39.582718</td>
#       <td id="T_5d7b8_row1_col4" class="data row1 col4" >-0.168514</td>
#       <td id="T_5d7b8_row1_col5" class="data row1 col5" >0.473699</td>
#     </tr>
#     <tr>
#       <th id="T_5d7b8_level0_row2" class="row_heading level0 row2" >SVR</th>
#       <td id="T_5d7b8_row2_col0" class="data row2 col0" >-5048.658620</td>
#       <td id="T_5d7b8_row2_col1" class="data row2 col1" >-60.023966</td>
#       <td id="T_5d7b8_row2_col2" class="data row2 col2" >0.118126</td>
#       <td id="T_5d7b8_row2_col3" class="data row2 col3" >-56.628030</td>
#       <td id="T_5d7b8_row2_col4" class="data row2 col4" >-0.259974</td>
#       <td id="T_5d7b8_row2_col5" class="data row2 col5" >0.144811</td>
#     </tr>
#     <tr>
#       <th id="T_5d7b8_level0_row3" class="row_heading level0 row3" >Decision Tree</th>
#       <td id="T_5d7b8_row3_col0" class="data row3 col0" >-6182.290382</td>
#       <td id="T_5d7b8_row3_col1" class="data row3 col1" >-63.268410</td>
#       <td id="T_5d7b8_row3_col2" class="data row3 col2" >-0.163793</td>
#       <td id="T_5d7b8_row3_col3" class="data row3 col3" >-52.000000</td>
#       <td id="T_5d7b8_row3_col4" class="data row3 col4" >-0.338953</td>
#       <td id="T_5d7b8_row3_col5" class="data row3 col5" >-0.138531</td>
#     </tr>
#     <tr>
#       <th id="T_5d7b8_level0_row4" class="row_heading level0 row4" >Random Forest</th>
#       <td id="T_5d7b8_row4_col0" class="data row4 col0" >-3531.504059</td>
#       <td id="T_5d7b8_row4_col1" class="data row4 col1" >-48.874558</td>
#       <td id="T_5d7b8_row4_col2" class="data row4 col2" >0.377519</td>
#       <td id="T_5d7b8_row4_col3" class="data row4 col3" >-46.012000</td>
#       <td id="T_5d7b8_row4_col4" class="data row4 col4" >-0.190840</td>
#       <td id="T_5d7b8_row4_col5" class="data row4 col5" >0.378257</td>
#     </tr>
#     <tr>
#       <th id="T_5d7b8_level0_row5" class="row_heading level0 row5" >k-NN</th>
#       <td id="T_5d7b8_row5_col0" class="data row5 col0" >-3685.557257</td>
#       <td id="T_5d7b8_row5_col1" class="data row5 col1" >-48.579219</td>
#       <td id="T_5d7b8_row5_col2" class="data row5 col2" >0.340087</td>
#       <td id="T_5d7b8_row5_col3" class="data row5 col3" >-41.080000</td>
#       <td id="T_5d7b8_row5_col4" class="data row5 col4" >-0.200909</td>
#       <td id="T_5d7b8_row5_col5" class="data row5 col5" >0.349525</td>
#     </tr>
#     <tr>
#       <th id="T_5d7b8_level0_row6" class="row_heading level0 row6" >Gradient Boosting</th>
#       <td id="T_5d7b8_row6_col0" class="data row6 col0" >-3468.666471</td>
#       <td id="T_5d7b8_row6_col1" class="data row6 col1" >-47.753218</td>
#       <td id="T_5d7b8_row6_col2" class="data row6 col2" >0.369805</td>
#       <td id="T_5d7b8_row6_col3" class="data row6 col3" >-42.706008</td>
#       <td id="T_5d7b8_row6_col4" class="data row6 col4" >-0.187251</td>
#       <td id="T_5d7b8_row6_col5" class="data row6 col5" >0.374789</td>
#     </tr>
#     <tr>
#       <th id="T_5d7b8_level0_row7" class="row_heading level0 row7" >Neural Network</th>
#       <td id="T_5d7b8_row7_col0" class="data row7 col0" >-3430.329560</td>
#       <td id="T_5d7b8_row7_col1" class="data row7 col1" >-46.440053</td>
#       <td id="T_5d7b8_row7_col2" class="data row7 col2" >0.394945</td>
#       <td id="T_5d7b8_row7_col3" class="data row7 col3" >-39.387247</td>
#       <td id="T_5d7b8_row7_col4" class="data row7 col4" >-0.194290</td>
#       <td id="T_5d7b8_row7_col5" class="data row7 col5" >0.362251</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Defining hyperparameter grids for individual models

param_grids = {
    'Ridge Regression': {
        'alpha': [0.01, 0.1, 1.0, 10.0, 100.0]
    },
    'Lasso Regression': {
        'alpha': [0.01, 0.1, 1.0, 10.0, 100.0]
    },
    'SVR': {
        'C': [0.1, 1, 10, 100],
        'gamma': [0.001, 0.01, 0.1, 1],
        'kernel': ['rbf', 'linear']
    },
    'Decision Tree': {
        'max_depth': [None, 10, 20, 30, 40, 50],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4]
    },
    'Random Forest': {
        'n_estimators': [10, 50, 100, 200],
        'max_depth': [None, 10, 20, 30],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4]
    },
    'k-NN': {
        'n_neighbors': [3, 5, 7, 9],
        'weights': ['uniform', 'distance'],
        'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']
    },
    'Gradient Boosting': {
        'n_estimators': [10, 50, 100, 200],
        'learning_rate': [0.001, 0.01, 0.1, 1],
        'max_depth': [3, 5, 7, 9]
    },
    'Neural Network': {
        'hidden_layer_sizes': [(50,), (100,), (100, 50), (100, 100)],
        'activation': ['relu', 'tanh'],
        'solver': ['adam', 'lbfgs'],
        'alpha': [0.0001, 0.001, 0.01],
        'learning_rate': ['constant', 'adaptive']
    }
}

# %%
best_models = []
for name, model in models:
    print(f"Tuning {name}...")
    grid_search = GridSearchCV(estimator=model, param_grid=param_grids[name], cv=cv, scoring='neg_mean_squared_error', n_jobs=-1)
    grid_search.fit(X_train, y_train)
    best_models.append((name, grid_search.best_estimator_, grid_search.best_params_))
    print(f"Best parameters for {name}: {grid_search.best_params_}")
# Out:
# Tuning Ridge Regression...
# Best parameters for Ridge Regression: {'alpha': 10.0}
# Tuning Lasso Regression...
# Best parameters for Lasso Regression: {'alpha': 1.0}
# Tuning SVR...
# Best parameters for SVR: {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
# Tuning Decision Tree...
# Best parameters for Decision Tree: {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Tuning Random Forest...
# Best parameters for Random Forest: {'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 50}
# Tuning k-NN...
# Best parameters for k-NN: {'algorithm': 'auto', 'n_neighbors': 7, 'weights': 'distance'}
# Tuning Gradient Boosting...
# Best parameters for Gradient Boosting: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}
# Tuning Neural Network...
# Best parameters for Neural Network: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# c:\Users\cezar\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10000) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
HPT_results = []
HPT_names = []

for name, model, params in best_models:
    scores = {metric: cross_val_score(model, X_train, y_train, cv=cv, scoring=scorer).mean() for metric, scorer in scoring.items()}
    HPT_results.append(scores)
    HPT_names.append(name)

HPT_results_df = pd.DataFrame(results, index=HPT_names)
# Out:
# c:\Users\cezar\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\cezar\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\cezar\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[88], line 9
#       6     HPT_results.append(scores)
#       7     HPT_names.append(name)
# ----> 9 HPT_results_df = pd.DataFrame(results, index=HTP_names)
#
# NameError: name 'HTP_names' is not defined

# %%
HPT_names
# Out:
# ['Ridge Regression',
#  'Lasso Regression',
#  'SVR',
#  'Decision Tree',
#  'Random Forest',
#  'k-NN',
#  'Gradient Boosting',
#  'Neural Network']

# %%
HPT_results_df.style.background_gradient(cmap="RdYlGn")
# Out:
#                    neg_mean_squared_error  neg_mean_absolute_error        r2  \
# Ridge Regression             -3017.384479               -44.988392  0.455947
# Lasso Regression             -3002.962386               -44.841481  0.460822
# SVR                          -5048.658620               -60.023966  0.118126
# Decision Tree                -6182.290382               -63.268410 -0.163793
# Random Forest                -3531.504059               -48.874558  0.377519
# k-NN                         -3685.557257               -48.579219  0.340087
# Gradient Boosting            -3468.666471               -47.753218  0.369805
# Neural Network               -3430.329560               -46.440053  0.394945
# Ridge Regression             -3015.866314               -44.883232  0.457486
# Lasso Regression             -3002.962386               -44.841481  0.460822
# SVR                          -2998.777784               -44.784518  0.461176
# Decision Tree                -4741.635775               -52.693704  0.154139
# Random Forest                -3435.793079               -47.608809  0.389074
# k-NN                         -3445.401476               -47.025107  0.385431
# Gradient Boosting            -3367.902120               -47.382644  0.394504
# Neural Network               -3518.427336               -46.457439  0.345869
# Ridge Regression             -3015.866314               -44.883232  0.457486
# Lasso Regression             -3002.962386               -44.841481  0.460822
# SVR                          -2998.777784               -44.784518  0.461176
# Decision Tree                -4741.635775               -52.693704  0.154139
# Random Forest                -3321.206783               -47.903698  0.402217
# k-NN                         -3445.401476               -47.025107  0.385431
# Gradient Boosting            -3354.881635               -47.355928  0.396739
# Neural Network               -3503.746525               -45.959072  0.385098
#
#                    neg_median_absolute_error  neg_mean_squared_log_error  \
# Ridge Regression                  -39.391947                   -0.171642
# Lasso Regression                  -39.582718                   -0.168514
# SVR                               -56.628030                   -0.259974
# Decision Tree                     -52.000000                   -0.338953
# Random Forest                     -46.012000                   -0.190840
# k-NN                              -41.080000                   -0.200909
# Gradient Boosting                 -42.706008                   -0.187251
# Neural Network                    -39.387247                   -0.194290
# Ridge Regression                  -39.976686                   -0.169126
# Lasso Regression                  -39.582718                   -0.168514
# SVR                               -40.067005                   -0.165521
# Decision Tree                     -42.593651                   -0.251846
# Random Forest                     -42.804579                   -0.185515
# k-NN                              -40.240673                   -0.187977
# Gradient Boosting                 -42.425230                   -0.183945
# Neural Network                    -37.132851                   -0.206552
# Ridge Regression                  -39.976686                   -0.169126
# Lasso Regression                  -39.582718                   -0.168514
# SVR                               -40.067005                   -0.165521
# Decision Tree                     -42.593651                   -0.251846
# Random Forest                     -44.368619                   -0.187369
# k-NN                              -40.240673                   -0.187977
# Gradient Boosting                 -43.386598                   -0.183579
# Neural Network                    -39.809996                   -0.199428
#
#                    explained_variance
# Ridge Regression             0.470067
# Lasso Regression             0.473699
# SVR                          0.144811
# Decision Tree               -0.138531
# Random Forest                0.378257
# k-NN                         0.349525
# Gradient Boosting            0.374789
# Neural Network               0.362251
# Ridge Regression             0.470520
# Lasso Regression             0.473699
# SVR                          0.473587
# Decision Tree                0.180548
# Random Forest                0.416521
# k-NN                         0.395019
# Gradient Boosting            0.408996
# Neural Network               0.371755
# Ridge Regression             0.470520
# Lasso Regression             0.473699
# SVR                          0.473587
# Decision Tree                0.180548
# Random Forest                0.416751
# k-NN                         0.395019
# Gradient Boosting            0.406889
# Neural Network               0.379419
