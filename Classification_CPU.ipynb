# %%
import numpy as np
import pandas as pd

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import make_scorer, accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, balanced_accuracy_score

#Classification algorithms
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier

# %%
data = load_breast_cancer()
X = data.data
y = data.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=345)

# %%
#Data standardization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
models = [
    ('Logistic Regression', LogisticRegression(max_iter=10000)),
    ('SVM', SVC(probability=True)),
    ('Decision Tree', DecisionTreeClassifier()),
    ('Random Forest', RandomForestClassifier()),
    ('k-NN', KNeighborsClassifier()),
    ('Gradient Boosting', GradientBoostingClassifier()),
    ('Naive Bayes', GaussianNB()),
    ('Neural Network', MLPClassifier(max_iter=1000))
]

# %%
#Cross-validation parameters
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=345)

# %%
scoring = {
    'accuracy': make_scorer(accuracy_score),
    'recall': make_scorer(recall_score),
    'precision': make_scorer(precision_score),
    'f1': make_scorer(f1_score),
    'roc_auc': make_scorer(roc_auc_score),
    'balanced_accuracy': make_scorer(balanced_accuracy_score),
    'specificity': make_scorer(lambda y_true, y_pred: recall_score(y_true, y_pred, pos_label=0))
}

# %%
#Default hyperparameters

results = []
names = []

for name, model in models:
    scores = {metric: cross_val_score(model, X_train, y_train, cv=cv, scoring=scorer).mean() for metric, scorer in scoring.items()}
    results.append(scores)
    names.append(name)

results_df = pd.DataFrame(results, index=names)

# %%
results_df.style.background_gradient(cmap="RdYlGn")
# Out:
# <style type="text/css">
# #T_449ea_row0_col0, #T_449ea_row0_col1, #T_449ea_row0_col2, #T_449ea_row0_col3, #T_449ea_row0_col4, #T_449ea_row0_col5, #T_449ea_row0_col6, #T_449ea_row1_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_449ea_row1_col0, #T_449ea_row1_col3 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_449ea_row1_col2 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_449ea_row1_col4, #T_449ea_row1_col5 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_449ea_row1_col6, #T_449ea_row7_col6 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_449ea_row2_col0, #T_449ea_row2_col1, #T_449ea_row6_col0, #T_449ea_row6_col2, #T_449ea_row6_col3, #T_449ea_row6_col4, #T_449ea_row6_col5, #T_449ea_row6_col6 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_449ea_row2_col2 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_449ea_row2_col3 {
#   background-color: #ce2827;
#   color: #f1f1f1;
# }
# #T_449ea_row2_col4 {
#   background-color: #f88950;
#   color: #f1f1f1;
# }
# #T_449ea_row2_col5 {
#   background-color: #e34933;
#   color: #f1f1f1;
# }
# #T_449ea_row2_col6 {
#   background-color: #e9f6a1;
#   color: #000000;
# }
# #T_449ea_row3_col0 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_449ea_row3_col1 {
#   background-color: #c1e57b;
#   color: #000000;
# }
# #T_449ea_row3_col2 {
#   background-color: #b5df74;
#   color: #000000;
# }
# #T_449ea_row3_col3 {
#   background-color: #bfe47a;
#   color: #000000;
# }
# #T_449ea_row3_col4 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_449ea_row3_col5 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_449ea_row3_col6, #T_449ea_row5_col6 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_449ea_row4_col0 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_449ea_row4_col1 {
#   background-color: #0f8446;
#   color: #f1f1f1;
# }
# #T_449ea_row4_col2 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_449ea_row4_col3 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_449ea_row4_col4, #T_449ea_row4_col5 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_449ea_row4_col6 {
#   background-color: #feeda1;
#   color: #000000;
# }
# #T_449ea_row5_col0 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_449ea_row5_col1 {
#   background-color: #ddf191;
#   color: #000000;
# }
# #T_449ea_row5_col2 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_449ea_row5_col3 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_449ea_row5_col4, #T_449ea_row5_col5 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_449ea_row6_col1 {
#   background-color: #fec877;
#   color: #000000;
# }
# #T_449ea_row7_col0 {
#   background-color: #3faa59;
#   color: #f1f1f1;
# }
# #T_449ea_row7_col1 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_449ea_row7_col2 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_449ea_row7_col3 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_449ea_row7_col4 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_449ea_row7_col5 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_449ea">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_449ea_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_449ea_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_449ea_level0_col2" class="col_heading level0 col2" >precision</th>
#       <th id="T_449ea_level0_col3" class="col_heading level0 col3" >f1</th>
#       <th id="T_449ea_level0_col4" class="col_heading level0 col4" >roc_auc</th>
#       <th id="T_449ea_level0_col5" class="col_heading level0 col5" >balanced_accuracy</th>
#       <th id="T_449ea_level0_col6" class="col_heading level0 col6" >specificity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_449ea_level0_row0" class="row_heading level0 row0" >Logistic Regression</th>
#       <td id="T_449ea_row0_col0" class="data row0 col0" >0.980220</td>
#       <td id="T_449ea_row0_col1" class="data row0 col1" >0.992982</td>
#       <td id="T_449ea_row0_col2" class="data row0 col2" >0.976441</td>
#       <td id="T_449ea_row0_col3" class="data row0 col3" >0.984404</td>
#       <td id="T_449ea_row0_col4" class="data row0 col4" >0.975903</td>
#       <td id="T_449ea_row0_col5" class="data row0 col5" >0.975903</td>
#       <td id="T_449ea_row0_col6" class="data row0 col6" >0.958824</td>
#     </tr>
#     <tr>
#       <th id="T_449ea_level0_row1" class="row_heading level0 row1" >SVM</th>
#       <td id="T_449ea_row1_col0" class="data row1 col0" >0.978022</td>
#       <td id="T_449ea_row1_col1" class="data row1 col1" >0.992982</td>
#       <td id="T_449ea_row1_col2" class="data row1 col2" >0.973220</td>
#       <td id="T_449ea_row1_col3" class="data row1 col3" >0.982724</td>
#       <td id="T_449ea_row1_col4" class="data row1 col4" >0.972962</td>
#       <td id="T_449ea_row1_col5" class="data row1 col5" >0.972962</td>
#       <td id="T_449ea_row1_col6" class="data row1 col6" >0.952941</td>
#     </tr>
#     <tr>
#       <th id="T_449ea_level0_row2" class="row_heading level0 row2" >Decision Tree</th>
#       <td id="T_449ea_row2_col0" class="data row2 col0" >0.936264</td>
#       <td id="T_449ea_row2_col1" class="data row2 col1" >0.933333</td>
#       <td id="T_449ea_row2_col2" class="data row2 col2" >0.961615</td>
#       <td id="T_449ea_row2_col3" class="data row2 col3" >0.952363</td>
#       <td id="T_449ea_row2_col4" class="data row2 col4" >0.941331</td>
#       <td id="T_449ea_row2_col5" class="data row2 col5" >0.936687</td>
#       <td id="T_449ea_row2_col6" class="data row2 col6" >0.935294</td>
#     </tr>
#     <tr>
#       <th id="T_449ea_level0_row3" class="row_heading level0 row3" >Random Forest</th>
#       <td id="T_449ea_row3_col0" class="data row3 col0" >0.958242</td>
#       <td id="T_449ea_row3_col1" class="data row3 col1" >0.971930</td>
#       <td id="T_449ea_row3_col2" class="data row3 col2" >0.966029</td>
#       <td id="T_449ea_row3_col3" class="data row3 col3" >0.972108</td>
#       <td id="T_449ea_row3_col4" class="data row3 col4" >0.959494</td>
#       <td id="T_449ea_row3_col5" class="data row3 col5" >0.954180</td>
#       <td id="T_449ea_row3_col6" class="data row3 col6" >0.947059</td>
#     </tr>
#     <tr>
#       <th id="T_449ea_level0_row4" class="row_heading level0 row4" >k-NN</th>
#       <td id="T_449ea_row4_col0" class="data row4 col0" >0.967033</td>
#       <td id="T_449ea_row4_col1" class="data row4 col1" >0.989474</td>
#       <td id="T_449ea_row4_col2" class="data row4 col2" >0.960405</td>
#       <td id="T_449ea_row4_col3" class="data row4 col3" >0.974289</td>
#       <td id="T_449ea_row4_col4" class="data row4 col4" >0.959443</td>
#       <td id="T_449ea_row4_col5" class="data row4 col5" >0.959443</td>
#       <td id="T_449ea_row4_col6" class="data row4 col6" >0.929412</td>
#     </tr>
#     <tr>
#       <th id="T_449ea_level0_row5" class="row_heading level0 row5" >Gradient Boosting</th>
#       <td id="T_449ea_row5_col0" class="data row5 col0" >0.958242</td>
#       <td id="T_449ea_row5_col1" class="data row5 col1" >0.968421</td>
#       <td id="T_449ea_row5_col2" class="data row5 col2" >0.968838</td>
#       <td id="T_449ea_row5_col3" class="data row5 col3" >0.964654</td>
#       <td id="T_449ea_row5_col4" class="data row5 col4" >0.952477</td>
#       <td id="T_449ea_row5_col5" class="data row5 col5" >0.952477</td>
#       <td id="T_449ea_row5_col6" class="data row5 col6" >0.947059</td>
#     </tr>
#     <tr>
#       <th id="T_449ea_level0_row6" class="row_heading level0 row6" >Naive Bayes</th>
#       <td id="T_449ea_row6_col0" class="data row6 col0" >0.936264</td>
#       <td id="T_449ea_row6_col1" class="data row6 col1" >0.954386</td>
#       <td id="T_449ea_row6_col2" class="data row6 col2" >0.945058</td>
#       <td id="T_449ea_row6_col3" class="data row6 col3" >0.949397</td>
#       <td id="T_449ea_row6_col4" class="data row6 col4" >0.930134</td>
#       <td id="T_449ea_row6_col5" class="data row6 col5" >0.930134</td>
#       <td id="T_449ea_row6_col6" class="data row6 col6" >0.905882</td>
#     </tr>
#     <tr>
#       <th id="T_449ea_level0_row7" class="row_heading level0 row7" >Neural Network</th>
#       <td id="T_449ea_row7_col0" class="data ro

# %% [markdown]
# Hyper parameter tuning

# %%
clf =  GridSearchCV(SVC(), {
    'C': [1,2,3,4,5,10,20],
    'kernel': ['linear', 'rbf'],
    'gamma': [1, 0.1, 0.01]
}, cv=5, scoring = ['accuracy', 'recall'], refit=False, return_train_score=True)
clf.fit(cancer.data, cancer.target)

df1 = pd.DataFrame(clf.cv_results_,columns=['param_C','param_kernel','param_gamma','mean_test_recall'])
df1
# Out:
#     param_C param_kernel  param_gamma  mean_test_recall
# 0         1       linear         1.00          0.969210
# 1         1          rbf         1.00          1.000000
# 2         1       linear         0.10          0.969210
# 3         1          rbf         0.10          1.000000
# 4         1       linear         0.01          0.969210
# 5         1          rbf         0.01          0.997183
# 6         2       linear         1.00          0.977660
# 7         2          rbf         1.00          1.000000
# 8         2       linear         0.10          0.977660
# 9         2          rbf         0.10          1.000000
# 10        2       linear         0.01          0.977660
# 11        2          rbf         0.01          0.994366
# 12        3       linear         1.00          0.974844
# 13        3          rbf         1.00          1.000000
# 14        3       linear         0.10          0.974844
# 15        3          rbf         0.10          1.000000
# 16        3       linear         0.01          0.974844
# 17        3          rbf         0.01          0.994366
# 18        4       linear         1.00          0.972027
# 19        4          rbf         1.00          1.000000
# 20        4       linear         0.10          0.972027
# 21        4          rbf         0.10          1.000000
# 22        4       linear         0.01          0.972027
# 23        4          rbf         0.01          0.994366
# 24        5       linear         1.00          0.969210
# 25        5          rbf         1.00          1.000000
# 26        5       linear         0.10          0.969210
# 27        5          rbf         0.10          1.000000
# 28        5       linear         0.01          0.969210
# 29        5          rbf         0.01          0.994366
# 30       10       linear         1.00          0.966393
# 31       10          rbf         1.00          1.000000
# 32       10       linear         0.10          0.966393
# 33       10          rbf         0.10          1.000000
# 34       10       linear         0.01          0.966393
# 35       10          rbf         0.01          0.994366
# 36       20       linear         1.00          0.966393
# 37       20          rbf         1.00          1.000000
# 38       20       linear         0.10          0.966393
# 39       20          rbf         0.10          1.000000
# 40       20       linear         0.01          0.966393
# 41       20          rbf         0.01          0.994366

# %%
df1.sort_values(by=['mean_test_recall'], ascending=False).head(15)
# Out:
#     param_C param_kernel  param_gamma  mean_test_recall
# 21        4          rbf         0.10          1.000000
# 33       10          rbf         0.10          1.000000
# 15        3          rbf         0.10          1.000000
# 25        5          rbf         1.00          1.000000
# 13        3          rbf         1.00          1.000000
# 27        5          rbf         0.10          1.000000
# 31       10          rbf         1.00          1.000000
# 19        4          rbf         1.00          1.000000
# 9         2          rbf         0.10          1.000000
# 7         2          rbf         1.00          1.000000
# 37       20          rbf         1.00          1.000000
# 3         1          rbf         0.10          1.000000
# 39       20          rbf         0.10          1.000000
# 1         1          rbf         1.00          1.000000
# 5         1          rbf         0.01          0.997183

# %%
clf =  GridSearchCV(KNeighborsClassifier(), {
    'n_neighbors': [1,3,5,7,9],
    'weights': ['uniform', 'distance'],
    'p': [1,2]
}, cv=5, scoring = ['accuracy', 'recall'], refit=False, return_train_score=True)
clf.fit(cancer.data, cancer.target)

df2 = pd.DataFrame(clf.cv_results_,columns=['param_n_neighbors','param_weights','param_p','mean_test_recall'])
df2
# Out:
#     param_n_neighbors param_weights  param_p  mean_test_recall
# 0                   1       uniform        1          0.957903
# 1                   1      distance        1          0.957903
# 2                   1       uniform        2          0.941197
# 3                   1      distance        2          0.941197
# 4                   3       uniform        1          0.963537
# 5                   3      distance        1          0.966315
# 6                   3       uniform        2          0.952308
# 7                   3      distance        2          0.957942
# 8                   5       uniform        1          0.969092
# 9                   5      distance        1          0.969092
# 10                  5       uniform        2          0.960759
# 11                  5      distance        2          0.963576
# 12                  7       uniform        1          0.971909
# 13                  7      distance        1          0.969092
# 14                  7       uniform        2          0.963537
# 15                  7      distance        2          0.966354
# 16                  9       uniform        1          0.977504
# 17                  9      distance        1          0.974687
# 18                  9       uniform        2          0.966315
# 19                  9      distance        2          0.966354

# %%
df2.sort_values(by=['mean_test_recall'], ascending=False).head()
# Out:
#     param_n_neighbors param_weights  param_p  mean_test_recall
# 16                  9       uniform        1          0.977504
# 17                  9      distance        1          0.974687
# 12                  7       uniform        1          0.971909
# 13                  7      distance        1          0.969092
# 8                   5       uniform        1          0.969092
